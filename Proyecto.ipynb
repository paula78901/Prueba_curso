# %% [markdown]
# <a href="https://colab.research.google.com/github/paula78901/Prueba_curso/blob/main/Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Este es texto dentro de un Notebook

# %%
print("hola mundo")
